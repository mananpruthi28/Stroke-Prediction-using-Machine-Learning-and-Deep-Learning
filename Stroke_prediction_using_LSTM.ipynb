# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,10)

# %%
import numpy as np
import io
from google.colab import files
uploaded = files.upload()
dataset = pd.read_csv(io.BytesIO(uploaded['stroke.csv']))
dataset
# Out:
#      <input type="file" id="files-a1352aff-147e-4934-8429-4b72dd69f596" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1352aff-147e-4934-8429-4b72dd69f596">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stroke.csv to stroke.csv
#          id  gender   age  ...   bmi   smoking_status stroke
# 0      9046    Male  67.0  ...  36.6  formerly smoked      1
# 1     51676  Female  61.0  ...   NaN     never smoked      1
# 2     31112    Male  80.0  ...  32.5     never smoked      1
# 3     60182  Female  49.0  ...  34.4           smokes      1
# 4      1665  Female  79.0  ...  24.0     never smoked      1
# ...     ...     ...   ...  ...   ...              ...    ...
# 5105  18234  Female  80.0  ...   NaN     never smoked      0
# 5106  44873  Female  81.0  ...  40.0     never smoked      0
# 5107  19723  Female  35.0  ...  30.6     never smoked      0
# 5108  37544    Male  51.0  ...  25.6  formerly smoked      0
# 5109  44679  Female  44.0  ...  26.2          Unknown      0
#
# [5110 rows x 12 columns]

# %%
dataset['bmi'].fillna(dataset['bmi'].mean(),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
dataset.drop('id',axis=1,inplace=True)

# %%
dataset['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %% [markdown]
# SAMPLING

# %%
# import imblearn
# print(imblearn.__version__)

# %%
# Stroke = len(dataset[dataset['stroke']==1])

# %%
# No_Stroke = len(dataset[dataset['stroke']==0])

# %%
# print(Stroke)
# print(No_Stroke)

# %%
# index_No_Stroke = dataset[dataset['stroke']==0].index

# index_Stroke = dataset[dataset['stroke']==1].index

# %%
# random_indices = np.random.choice(index_No_Stroke, Stroke,replace='False')

# %%
# len(random_indices)

# %%
# under_sample_indices = np.concatenate([index_Stroke,random_indices])

# %%
# under_sample_df = dataset.iloc[under_sample_indices]

# %%
# under_sample_df

# %%
# from collections import Counter
# Counter(under_sample_df['stroke'])

# %%
# under_sample_class_counts = pd.value_counts(under_sample_df['stroke'])
# under_sample_class_counts.plot(kind = 'bar')
# x_under = under_sample_df.loc[:, under_sample_df.columns != 'stroke']
# y_under = under_sample_df.loc[:,under_sample_df.columns == 'stroke']
# x_under.columns
# y_under.columns

# %%
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()

# %%
gender=encode.fit_transform(dataset['gender'])
ever_married=encode.fit_transform(dataset['ever_married'])
work_type=encode.fit_transform(dataset['work_type'])
smoking_status=encode.fit_transform(dataset['smoking_status'])
Residence_type=encode.fit_transform(dataset['Residence_type'])

# %%
dataset['gender']=gender
dataset['ever_married']=ever_married
dataset['work_type']=work_type
dataset['smoking_status']=smoking_status
dataset['Residence_type']=Residence_type

# %%
dataset
# Out:
#       gender   age  hypertension  ...        bmi  smoking_status  stroke
# 0          1  67.0             0  ...  36.600000               1       1
# 1          0  61.0             0  ...  28.893237               2       1
# 2          1  80.0             0  ...  32.500000               2       1
# 3          0  49.0             0  ...  34.400000               3       1
# 4          0  79.0             1  ...  24.000000               2       1
# ...      ...   ...           ...  ...        ...             ...     ...
# 5105       0  80.0             1  ...  28.893237               2       0
# 5106       0  81.0             0  ...  40.000000               2       0
# 5107       0  35.0             0  ...  30.600000               2       0
# 5108       1  51.0             0  ...  25.600000               1       0
# 5109       0  44.0             0  ...  26.200000               0       0
#
# [5110 rows x 11 columns]

# %%
dataset.drop('gender',axis=1,inplace=True)
dataset.drop('Residence_type',axis=1,inplace=True)

# %%
dataset.head()
# Out:
#     age  hypertension  heart_disease  ...        bmi  smoking_status  stroke
# 0  67.0             0              1  ...  36.600000               1       1
# 1  61.0             0              0  ...  28.893237               2       1
# 2  80.0             0              1  ...  32.500000               2       1
# 3  49.0             0              0  ...  34.400000               3       1
# 4  79.0             1              0  ...  24.000000               2       1
#
# [5 rows x 9 columns]

# %%
dataset.shape
# Out:
# (5110, 9)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                5110 non-null   float64
#  1   hypertension       5110 non-null   int64
#  2   heart_disease      5110 non-null   int64
#  3   ever_married       5110 non-null   int64
#  4   work_type          5110 non-null   int64
#  5   avg_glucose_level  5110 non-null   float64
#  6   bmi                5110 non-null   float64
#  7   smoking_status     5110 non-null   int64
#  8   stroke             5110 non-null   int64
# dtypes: float64(3), int64(6)
# memory usage: 359.4 KB

# %%
X=dataset.drop('stroke',axis=1)

# %%
X.head()
# Out:
#     age  hypertension  ...        bmi  smoking_status
# 0  67.0             0  ...  36.600000               1
# 1  61.0             0  ...  28.893237               2
# 2  80.0             0  ...  32.500000               2
# 3  49.0             0  ...  34.400000               3
# 4  79.0             1  ...  24.000000               2
#
# [5 rows x 8 columns]

# %%
Y=dataset['stroke']

# %%
Y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.2,random_state=97)

# %%
X_train
# Out:
#        age  hypertension  ...        bmi  smoking_status
# 10    81.0             1  ...  29.700000               2
# 4576  53.0             0  ...  27.700000               3
# 1021  37.0             0  ...  27.800000               2
# 4296  64.0             0  ...  31.100000               1
# 4490  19.0             0  ...  18.500000               3
# ...    ...           ...  ...        ...             ...
# 3356  55.0             0  ...  18.100000               1
# 3271  36.0             0  ...  31.600000               1
# 2997  71.0             0  ...  28.893237               1
# 105   58.0             0  ...  28.893237               3
# 2467  78.0             0  ...  28.800000               1
#
# [4088 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()

# %%
X_train_std=std.fit_transform(X_train)
X_test_std=std.transform(X_test)

# %%
dataset
# Out:
#        age  hypertension  heart_disease  ...        bmi  smoking_status  stroke
# 0     67.0             0              1  ...  36.600000               1       1
# 1     61.0             0              0  ...  28.893237               2       1
# 2     80.0             0              1  ...  32.500000               2       1
# 3     49.0             0              0  ...  34.400000               3       1
# 4     79.0             1              0  ...  24.000000               2       1
# ...    ...           ...            ...  ...        ...             ...     ...
# 5105  80.0             1              0  ...  28.893237               2       0
# 5106  81.0             0              0  ...  40.000000               2       0
# 5107  35.0             0              0  ...  30.600000               2       0
# 5108  51.0             0              0  ...  25.600000               1       0
# 5109  44.0             0              0  ...  26.200000               0       0
#
# [5110 rows x 9 columns]

# %% [markdown]
# LSTM

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
#from keras.optimizers import Adam

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import CuDNNLSTM, Dense, Dropout, LSTM

# %%
n_features= X.shape[1]
#LSTM model 
import os
import numpy as np
import pandas as pd
import random, math
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle as skshuffle
from sklearn.model_selection import train_test_split as sk_train_test_split
from tensorflow.keras.layers import Convolution1D, Dense, Flatten, GlobalAveragePooling1D, AveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, GlobalAveragePooling2D, Conv2D
from tensorflow.keras.layers import Dropout, AveragePooling2D, LSTM, GRU
from sklearn.metrics import mean_squared_error
from time import time
from tensorflow.keras.callbacks import TensorBoard
import tensorflow as tf

from tensorflow.keras import regularizers

os.environ["PYTHONHASHSEED"] = "0"
np.random.seed(64)
random.seed(64)
tf.compat.v1.set_random_seed(64)
from keras import backend as K
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph())
from tensorflow.compat.v1.keras import backend as K
K.set_session(sess)
X_train_std= np.array(X_train_std).reshape(len(X_train_std), 1, n_features)
X_test_std= np.array(X_test_std).reshape(len(X_test_std), 1, n_features)

# %%
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced', np.unique(Y_train),Y_train)
class_weights = dict(enumerate(class_weights))

# %%
model2 = Sequential()
model2.add(LSTM(100, return_sequences=True, input_shape=(1, X_train_std.shape[2])))

model2.add(LSTM(50, return_sequences=False))
#model.add(Dropout(0.2))
model2.add(Dense(1, activation='sigmoid'))
from tensorflow.keras.optimizers import SGD
# model.compile(loss='binary_crossentropy', optimizer=SGD(), metrics=['binary_accuracy'])
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model2.summary()
# fit model
model2.fit(X_train_std, Y_train, epochs=100, batch_size=34, class_weight=class_weights, shuffle=True)
#
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 1, 100)            43600
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 73,851
# Trainable params: 73,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 121/121 [==============================] - 5s 8ms/step - loss: 0.6102 - accuracy: 0.5807
# Epoch 2/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4979 - accuracy: 0.6678
# Epoch 3/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4788 - accuracy: 0.7260
# Epoch 4/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4734 - accuracy: 0.7123
# Epoch 5/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4726 - accuracy: 0.7228
# Epoch 6/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4724 - accuracy: 0.7221
# Epoch 7/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4686 - accuracy: 0.7209
# Epoch 8/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4692 - accuracy: 0.7238
# Epoch 9/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4667 - accuracy: 0.7231
# Epoch 10/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4662 - accuracy: 0.7260
# Epoch 11/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4666 - accuracy: 0.7175
# Epoch 12/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4657 - accuracy: 0.7177
# Epoch 13/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4649 - accuracy: 0.7334
# Epoch 14/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4637 - accuracy: 0.7182
# Epoch 15/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4616 - accuracy: 0.7231
# Epoch 16/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4626 - accuracy: 0.7177
# Epoch 17/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4614 - accuracy: 0.7339
# Epoch 18/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4571 - accuracy: 0.7025
# Epoch 19/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4625 - accuracy: 0.7282
# Epoch 20/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4604 - accuracy: 0.7351
# Epoch 21/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4584 - accuracy: 0.7307
# Epoch 22/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4618 - accuracy: 0.7312
# Epoch 23/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4569 - accuracy: 0.7065
# Epoch 24/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4579 - accuracy: 0.7214
# Epoch 25/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4555 - accuracy: 0.7160
# Epoch 26/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4548 - accuracy: 0.7238
# Epoch 27/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4541 - accuracy: 0.7299
# Epoch 28/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4523 - accuracy: 0.7295
# Epoch 29/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4541 - accuracy: 0.7285
# Epoch 30/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4506 - accuracy: 0.7255
# Epoch 31/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4497 - accuracy: 0.7184
# Epoch 32/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4503 - accuracy: 0.7321
# Epoch 33/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4468 - accuracy: 0.7219
# Epoch 34/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4473 - accuracy: 0.7353
# Epoch 35/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4454 - accuracy: 0.7309
# Epoch 36/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4464 - accuracy: 0.7194
# Epoch 37/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4445 - accuracy: 0.7343
# Epoch 38/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4430 - accuracy: 0.7253
# Epoch 39/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4422 - accuracy: 0.7331
# Epoch 40/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4419 - accuracy: 0.7304
# Epoch 41/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4415 - accuracy: 0.7128
# Epoch 42/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4377 - accuracy: 0.7268
# Epoch 43/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4397 - accuracy: 0.7304
# Epoch 44/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4374 - accuracy: 0.7341
# Epoch 45/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4379 - accuracy: 0.7329
# Epoch 46/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4358 - accuracy: 0.7385
# Epoch 47/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4334 - accuracy: 0.7214
# Epoch 48/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4335 - accuracy: 0.7380
# Epoch 49/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4314 - accuracy: 0.7307
# Epoch 50/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4305 - accuracy: 0.7405
# Epoch 51/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4291 - accuracy: 0.7282
# Epoch 52/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4294 - accuracy: 0.7412
# Epoch 53/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4264 - accuracy: 0.7390
# Epoch 54/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4270 - accuracy: 0.7363
# Epoch 55/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4238 - accuracy: 0.7368
# Epoch 56/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4252 - accuracy: 0.7434
# Epoch 57/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4232 - accuracy: 0.7351
# Epoch 58/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4228 - accuracy: 0.7454
# Epoch 59/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4217 - accuracy: 0.7331
# Epoch 60/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4200 - accuracy: 0.7414
# Epoch 61/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4188 - accuracy: 0.7434
# Epoch 62/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4183 - accuracy: 0.7454
# Epoch 63/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4176 - accuracy: 0.7343
# Epoch 64/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4162 - accuracy: 0.7454
# Epoch 65/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4152 - accuracy: 0.7485
# Epoch 66/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4147 - accuracy: 0.7449
# Epoch 67/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4154 - accuracy: 0.7407
# Epoch 68/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4127 - accuracy: 0.7466
# Epoch 69/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4106 - accuracy: 0.7424
# Epoch 70/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4108 - accuracy: 0.7400
# Epoch 71/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4100 - accuracy: 0.7551
# Epoch 72/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4102 - accuracy: 0.7424
# Epoch 73/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4069 - accuracy: 0.7485
# Epoch 74/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4054 - accuracy: 0.7463
# Epoch 75/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4069 - accuracy: 0.7522
# Epoch 76/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4040 - accuracy: 0.7493
# Epoch 77/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4044 - accuracy: 0.7502
# Epoch 78/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4036 - accuracy: 0.7534
# Epoch 79/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.4039 - accuracy: 0.7527
# Epoch 80/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4018 - accuracy: 0.7454
# Epoch 81/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4000 - accuracy: 0.7520
# Epoch 82/100
# 121/121 [==============================] - 1s 8ms/step - loss: 0.4006 - accuracy: 0.7507
# Epoch 83/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3987 - accuracy: 0.7603
# Epoch 84/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3979 - accuracy: 0.7600
# Epoch 85/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3961 - accuracy: 0.7635
# Epoch 86/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3965 - accuracy: 0.7617
# Epoch 87/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3936 - accuracy: 0.7600
# Epoch 88/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3928 - accuracy: 0.7715
# Epoch 89/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3914 - accuracy: 0.7615
# Epoch 90/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3931 - accuracy: 0.7698
# Epoch 91/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3901 - accuracy: 0.7715
# Epoch 92/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3888 - accuracy: 0.7676
# Epoch 93/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3897 - accuracy: 0.7710
# Epoch 94/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3887 - accuracy: 0.7791
# Epoch 95/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3882 - accuracy: 0.7701
# Epoch 96/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3857 - accuracy: 0.7784
# Epoch 97/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3861 - accuracy: 0.7730
# Epoch 98/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3839 - accuracy: 0.7801
# Epoch 99/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3837 - accuracy: 0.7752
# Epoch 100/100
# 121/121 [==============================] - 1s 9ms/step - loss: 0.3830 - accuracy: 0.7737

# %%
model2 = Sequential()
model2.add(GRU(50,activation='sigmoid', return_sequences=True, input_shape=(1, X_train_std.shape[2])))

model2.add(GRU(25, return_sequences=False))
#model.add(Dropout(0.2))
model2.add(Dense(1, activation='sigmoid'))
from tensorflow.keras.optimizers import SGD
# model.compile(loss='binary_crossentropy', optimizer=SGD(), metrics=['binary_accuracy'])
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model2.summary()
# fit model
model2.fit(X_train_std, Y_train, epochs=1000, batch_size=34, class_weight=class_weights, shuffle=True)
#
# Out:
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_8 (GRU)                  (None, 1, 50)             9000
# _________________________________________________________________
# gru_9 (GRU)                  (None, 25)                5775
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 14,801
# Trainable params: 14,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 121/121 [==============================] - 6s 14ms/step - loss: 0.6418 - accuracy: 0.6700
# Epoch 2/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.5362 - accuracy: 0.6866
# Epoch 3/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.5001 - accuracy: 0.7402
# Epoch 4/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4867 - accuracy: 0.7172
# Epoch 5/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4816 - accuracy: 0.7263
# Epoch 6/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4794 - accuracy: 0.7287
# Epoch 7/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4775 - accuracy: 0.7250
# Epoch 8/1000
# 121/121 [==============================] - 2s 13ms/step - loss: 0.4740 - accuracy: 0.7224
# Epoch 9/1000
# 121/121 [==============================] - 2s 13ms/step - loss: 0.4736 - accuracy: 0.7356
# Epoch 10/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4724 - accuracy: 0.7285
# Epoch 11/1000
# 121/121 [==============================] - 2s 13ms/step - loss: 0.4731 - accuracy: 0.7180
# Epoch 12/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4739 - accuracy: 0.7290
# Epoch 13/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4716 - accuracy: 0.7309
# Epoch 14/1000
# 121/121 [==============================] - 2s 13ms/step - loss: 0.4723 - accuracy: 0.7158
# Epoch 15/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4724 - accuracy: 0.7246
# Epoch 16/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4739 - accuracy: 0.7175
# Epoch 17/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4695 - accuracy: 0.7397
# Epoch 18/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4668 - accuracy: 0.7099
# Epoch 19/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4732 - accuracy: 0.7248
# Epoch 20/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4709 - accuracy: 0.7314
# Epoch 21/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4700 - accuracy: 0.7297
# Epoch 22/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4709 - accuracy: 0.7297
# Epoch 23/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4718 - accuracy: 0.7057
# Epoch 24/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4719 - accuracy: 0.7199
# Epoch 25/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4705 - accuracy: 0.7204
# Epoch 26/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4680 - accuracy: 0.7177
# Epoch 27/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4710 - accuracy: 0.7273
# Epoch 28/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4698 - accuracy: 0.7189
# Epoch 29/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4710 - accuracy: 0.7221
# Epoch 30/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4709 - accuracy: 0.7233
# Epoch 31/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4691 - accuracy: 0.7209
# Epoch 32/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4693 - accuracy: 0.7199
# Epoch 33/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4689 - accuracy: 0.7172
# Epoch 34/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4674 - accuracy: 0.7324
# Epoch 35/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4689 - accuracy: 0.7231
# Epoch 36/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4721 - accuracy: 0.7047
# Epoch 37/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4691 - accuracy: 0.7241
# Epoch 38/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4670 - accuracy: 0.7162
# Epoch 39/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4687 - accuracy: 0.7263
# Epoch 40/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4694 - accuracy: 0.7221
# Epoch 41/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4706 - accuracy: 0.7062
# Epoch 42/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4664 - accuracy: 0.7160
# Epoch 43/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4674 - accuracy: 0.7158
# Epoch 44/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4682 - accuracy: 0.7224
# Epoch 45/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4667 - accuracy: 0.7290
# Epoch 46/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4658 - accuracy: 0.7180
# Epoch 47/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4665 - accuracy: 0.7089
# Epoch 48/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4667 - accuracy: 0.7268
# Epoch 49/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4671 - accuracy: 0.7145
# Epoch 50/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4664 - accuracy: 0.7199
# Epoch 51/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4662 - accuracy: 0.7175
# Epoch 52/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4665 - accuracy: 0.7263
# Epoch 53/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4668 - accuracy: 0.7082
# Epoch 54/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4651 - accuracy: 0.7206
# Epoch 55/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4675 - accuracy: 0.7246
# Epoch 56/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4653 - accuracy: 0.7236
# Epoch 57/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4641 - accuracy: 0.7226
# Epoch 58/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4625 - accuracy: 0.7285
# Epoch 59/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4645 - accuracy: 0.7047
# Epoch 60/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4650 - accuracy: 0.7277
# Epoch 61/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4645 - accuracy: 0.7170
# Epoch 62/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4630 - accuracy: 0.7263
# Epoch 63/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4634 - accuracy: 0.7084
# Epoch 64/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4656 - accuracy: 0.7277
# Epoch 65/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4644 - accuracy: 0.7194
# Epoch 66/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4625 - accuracy: 0.7189
# Epoch 67/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4636 - accuracy: 0.7224
# Epoch 68/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4620 - accuracy: 0.7206
# Epoch 69/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4630 - accuracy: 0.7160
# Epoch 70/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4623 - accuracy: 0.7189
# Epoch 71/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4617 - accuracy: 0.7246
# Epoch 72/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4615 - accuracy: 0.7077
# Epoch 73/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4610 - accuracy: 0.7309
# Epoch 74/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4608 - accuracy: 0.7170
# Epoch 75/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4619 - accuracy: 0.7348
# Epoch 76/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4605 - accuracy: 0.7143
# Epoch 77/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4619 - accuracy: 0.7140
# Epoch 78/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4622 - accuracy: 0.7302
# Epoch 79/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4620 - accuracy: 0.7160
# Epoch 80/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4600 - accuracy: 0.7189
# Epoch 81/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4585 - accuracy: 0.7104
# Epoch 82/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4592 - accuracy: 0.7099
# Epoch 83/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4598 - accuracy: 0.7248
# Epoch 84/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4578 - accuracy: 0.7258
# Epoch 85/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4586 - accuracy: 0.7263
# Epoch 86/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4579 - accuracy: 0.7265
# Epoch 87/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4570 - accuracy: 0.7106
# Epoch 88/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4567 - accuracy: 0.7383
# Epoch 89/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4557 - accuracy: 0.7106
# Epoch 90/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4573 - accuracy: 0.7297
# Epoch 91/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4563 - accuracy: 0.7219
# Epoch 92/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4577 - accuracy: 0.7180
# Epoch 93/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4563 - accuracy: 0.7248
# Epoch 94/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4560 - accuracy: 0.7228
# Epoch 95/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4556 - accuracy: 0.7177
# Epoch 96/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4562 - accuracy: 0.7250
# Epoch 97/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4544 - accuracy: 0.7155
# Epoch 98/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4546 - accuracy: 0.7395
# Epoch 99/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4539 - accuracy: 0.7153
# Epoch 100/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4554 - accuracy: 0.7211
# Epoch 101/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4532 - accuracy: 0.7287
# Epoch 102/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4532 - accuracy: 0.7312
# Epoch 103/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4513 - accuracy: 0.7126
# Epoch 104/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4530 - accuracy: 0.7295
# Epoch 105/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4534 - accuracy: 0.7370
# Epoch 106/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4512 - accuracy: 0.7241
# Epoch 107/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4528 - accuracy: 0.7204
# Epoch 108/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4515 - accuracy: 0.7224
# Epoch 109/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4493 - accuracy: 0.7255
# Epoch 110/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4492 - accuracy: 0.7353
# Epoch 111/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4506 - accuracy: 0.7158
# Epoch 112/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4478 - accuracy: 0.7082
# Epoch 113/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4507 - accuracy: 0.7255
# Epoch 114/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4502 - accuracy: 0.7236
# Epoch 115/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4481 - accuracy: 0.7258
# Epoch 116/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4489 - accuracy: 0.7321
# Epoch 117/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4479 - accuracy: 0.7334
# Epoch 118/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4464 - accuracy: 0.7258
# Epoch 119/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4488 - accuracy: 0.7260
# Epoch 120/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4467 - accuracy: 0.7255
# Epoch 121/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4480 - accuracy: 0.7280
# Epoch 122/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4462 - accuracy: 0.7287
# Epoch 123/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4460 - accuracy: 0.7238
# Epoch 124/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4447 - accuracy: 0.7253
# Epoch 125/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4455 - accuracy: 0.7324
# Epoch 126/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4452 - accuracy: 0.7331
# Epoch 127/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4439 - accuracy: 0.7299
# Epoch 128/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4457 - accuracy: 0.7319
# Epoch 129/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4451 - accuracy: 0.7238
# Epoch 130/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4453 - accuracy: 0.7304
# Epoch 131/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4433 - accuracy: 0.7265
# Epoch 132/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4431 - accuracy: 0.7248
# Epoch 133/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4416 - accuracy: 0.7321
# Epoch 134/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4424 - accuracy: 0.7314
# Epoch 135/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4432 - accuracy: 0.7265
# Epoch 136/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4413 - accuracy: 0.7383
# Epoch 137/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4408 - accuracy: 0.7390
# Epoch 138/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4401 - accuracy: 0.7275
# Epoch 139/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4399 - accuracy: 0.7280
# Epoch 140/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4385 - accuracy: 0.7282
# Epoch 141/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4379 - accuracy: 0.7461
# Epoch 142/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4377 - accuracy: 0.7273
# Epoch 143/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4375 - accuracy: 0.7312
# Epoch 144/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4385 - accuracy: 0.7358
# Epoch 145/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.4370 - accuracy: 0.7361
# Epoch 146/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4363 - accuracy: 0.7292
# Epoch 147/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4362 - accuracy: 0.7339
# Epoch 148/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4359 - accuracy: 0.7265
# Epoch 149/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4341 - accuracy: 0.7317
# Epoch 150/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4350 - accuracy: 0.7233
# Epoch 151/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4349 - accuracy: 0.7446
# Epoch 152/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4321 - accuracy: 0.7395
# Epoch 153/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4340 - accuracy: 0.7282
# Epoch 154/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4329 - accuracy: 0.7346
# Epoch 155/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4304 - accuracy: 0.7370
# Epoch 156/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4305 - accuracy: 0.7351
# Epoch 157/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4301 - accuracy: 0.7380
# Epoch 158/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4310 - accuracy: 0.7275
# Epoch 159/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4292 - accuracy: 0.7314
# Epoch 160/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4291 - accuracy: 0.7241
# Epoch 161/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4306 - accuracy: 0.7390
# Epoch 162/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4282 - accuracy: 0.7490
# Epoch 163/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4272 - accuracy: 0.7427
# Epoch 164/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4292 - accuracy: 0.7326
# Epoch 165/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4265 - accuracy: 0.7334
# Epoch 166/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4268 - accuracy: 0.7539
# Epoch 167/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4234 - accuracy: 0.7346
# Epoch 168/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4245 - accuracy: 0.7312
# Epoch 169/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4242 - accuracy: 0.7473
# Epoch 170/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4245 - accuracy: 0.7446
# Epoch 171/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4239 - accuracy: 0.7395
# Epoch 172/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4249 - accuracy: 0.7358
# Epoch 173/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4225 - accuracy: 0.7370
# Epoch 174/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4214 - accuracy: 0.7368
# Epoch 175/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4204 - accuracy: 0.7510
# Epoch 176/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4217 - accuracy: 0.7334
# Epoch 177/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4202 - accuracy: 0.7380
# Epoch 178/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4189 - accuracy: 0.7473
# Epoch 179/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4194 - accuracy: 0.7424
# Epoch 180/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4173 - accuracy: 0.7412
# Epoch 181/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4171 - accuracy: 0.7522
# Epoch 182/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4186 - accuracy: 0.7365
# Epoch 183/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4137 - accuracy: 0.7432
# Epoch 184/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4181 - accuracy: 0.7507
# Epoch 185/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4149 - accuracy: 0.7476
# Epoch 186/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4154 - accuracy: 0.7449
# Epoch 187/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4153 - accuracy: 0.7304
# Epoch 188/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4166 - accuracy: 0.7498
# Epoch 189/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4136 - accuracy: 0.7527
# Epoch 190/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4105 - accuracy: 0.7485
# Epoch 191/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4123 - accuracy: 0.7502
# Epoch 192/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4115 - accuracy: 0.7524
# Epoch 193/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4112 - accuracy: 0.7498
# Epoch 194/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4098 - accuracy: 0.7544
# Epoch 195/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4101 - accuracy: 0.7561
# Epoch 196/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4098 - accuracy: 0.7613
# Epoch 197/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4121 - accuracy: 0.7517
# Epoch 198/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4104 - accuracy: 0.7449
# Epoch 199/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4079 - accuracy: 0.7605
# Epoch 200/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4067 - accuracy: 0.7529
# Epoch 201/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4059 - accuracy: 0.7593
# Epoch 202/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4053 - accuracy: 0.7534
# Epoch 203/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4041 - accuracy: 0.7615
# Epoch 204/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4049 - accuracy: 0.7683
# Epoch 205/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4055 - accuracy: 0.7505
# Epoch 206/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4033 - accuracy: 0.7622
# Epoch 207/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4028 - accuracy: 0.7561
# Epoch 208/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4014 - accuracy: 0.7664
# Epoch 209/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4019 - accuracy: 0.7603
# Epoch 210/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4012 - accuracy: 0.7515
# Epoch 211/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.4002 - accuracy: 0.7679
# Epoch 212/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3979 - accuracy: 0.7517
# Epoch 213/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3980 - accuracy: 0.7681
# Epoch 214/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3990 - accuracy: 0.7674
# Epoch 215/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.4008 - accuracy: 0.7691
# Epoch 216/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3975 - accuracy: 0.7593
# Epoch 217/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3980 - accuracy: 0.7613
# Epoch 218/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3983 - accuracy: 0.7735
# Epoch 219/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3989 - accuracy: 0.7591
# Epoch 220/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3971 - accuracy: 0.7781
# Epoch 221/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3983 - accuracy: 0.7490
# Epoch 222/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3957 - accuracy: 0.7683
# Epoch 223/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3943 - accuracy: 0.7652
# Epoch 224/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3943 - accuracy: 0.7715
# Epoch 225/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3929 - accuracy: 0.7696
# Epoch 226/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3950 - accuracy: 0.7586
# Epoch 227/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3945 - accuracy: 0.7828
# Epoch 228/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3918 - accuracy: 0.7671
# Epoch 229/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3922 - accuracy: 0.7730
# Epoch 230/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3908 - accuracy: 0.7732
# Epoch 231/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3918 - accuracy: 0.7701
# Epoch 232/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3923 - accuracy: 0.7806
# Epoch 233/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3913 - accuracy: 0.7703
# Epoch 234/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3886 - accuracy: 0.7772
# Epoch 235/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3895 - accuracy: 0.7789
# Epoch 236/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3878 - accuracy: 0.7798
# Epoch 237/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3855 - accuracy: 0.7737
# Epoch 238/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3869 - accuracy: 0.7688
# Epoch 239/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3891 - accuracy: 0.7769
# Epoch 240/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3882 - accuracy: 0.7774
# Epoch 241/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3846 - accuracy: 0.7791
# Epoch 242/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.3885 - accuracy: 0.7652
# Epoch 243/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3859 - accuracy: 0.7781
# Epoch 244/1000
# 121/121 [==============================] - 2s 14ms/step - loss: 0.3850 - accuracy: 0.7747
# Epoch 245/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3871 - accuracy: 0.7879
# Epoch 246/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3825 - accuracy: 0.7737
# Epoch 247/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3842 - accuracy: 0.7764
# Epoch 248/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3835 - accuracy: 0.7840
# Epoch 249/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3828 - accuracy: 0.7754
# Epoch 250/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3830 - accuracy: 0.7825
# Epoch 251/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3840 - accuracy: 0.7891
# Epoch 252/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3833 - accuracy: 0.7847
# Epoch 253/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3787 - accuracy: 0.7759
# Epoch 254/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3847 - accuracy: 0.7852
# Epoch 255/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3808 - accuracy: 0.7862
# Epoch 256/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3799 - accuracy: 0.7776
# Epoch 257/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3766 - accuracy: 0.7833
# Epoch 258/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3801 - accuracy: 0.7862
# Epoch 259/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3792 - accuracy: 0.7911
# Epoch 260/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3794 - accuracy: 0.7798
# Epoch 261/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3840 - accuracy: 0.7676
# Epoch 262/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3777 - accuracy: 0.7896
# Epoch 263/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3760 - accuracy: 0.7823
# Epoch 264/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3753 - accuracy: 0.7948
# Epoch 265/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3758 - accuracy: 0.7857
# Epoch 266/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3756 - accuracy: 0.7789
# Epoch 267/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3741 - accuracy: 0.7891
# Epoch 268/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3730 - accuracy: 0.7840
# Epoch 269/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3741 - accuracy: 0.7921
# Epoch 270/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3748 - accuracy: 0.7943
# Epoch 271/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3723 - accuracy: 0.7860
# Epoch 272/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3737 - accuracy: 0.7894
# Epoch 273/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3730 - accuracy: 0.7945
# Epoch 274/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3736 - accuracy: 0.7862
# Epoch 275/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3708 - accuracy: 0.7855
# Epoch 276/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3708 - accuracy: 0.7921
# Epoch 277/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3705 - accuracy: 0.7901
# Epoch 278/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3723 - accuracy: 0.7794
# Epoch 279/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3698 - accuracy: 0.7896
# Epoch 280/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3697 - accuracy: 0.7918
# Epoch 281/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.3692 - accuracy: 0.7811
# Epoch 282/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3673 - accuracy: 0.7882
# Epoch 283/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3694 - accuracy: 0.7901
# Epoch 284/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3681 - accuracy: 0.7896
# Epoch 285/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3687 - accuracy: 0.7972
# Epoch 286/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3669 - accuracy: 0.7957
# Epoch 287/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3662 - accuracy: 0.7997
# Epoch 288/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3643 - accuracy: 0.7984
# Epoch 289/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3673 - accuracy: 0.7838
# Epoch 290/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3644 - accuracy: 0.7992
# Epoch 291/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3642 - accuracy: 0.7931
# Epoch 292/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3678 - accuracy: 0.7855
# Epoch 293/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3652 - accuracy: 0.7953
# Epoch 294/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3636 - accuracy: 0.7921
# Epoch 295/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3615 - accuracy: 0.7864
# Epoch 296/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3629 - accuracy: 0.7950
# Epoch 297/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3618 - accuracy: 0.7970
# Epoch 298/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3598 - accuracy: 0.7975
# Epoch 299/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3585 - accuracy: 0.7850
# Epoch 300/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3624 - accuracy: 0.8043
# Epoch 301/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3599 - accuracy: 0.7884
# Epoch 302/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3587 - accuracy: 0.7933
# Epoch 303/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3591 - accuracy: 0.7957
# Epoch 304/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3581 - accuracy: 0.7970
# Epoch 305/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3577 - accuracy: 0.8004
# Epoch 306/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3588 - accuracy: 0.7921
# Epoch 307/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3574 - accuracy: 0.7977
# Epoch 308/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3580 - accuracy: 0.7955
# Epoch 309/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3570 - accuracy: 0.7904
# Epoch 310/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3568 - accuracy: 0.7874
# Epoch 311/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3531 - accuracy: 0.8058
# Epoch 312/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3541 - accuracy: 0.7997
# Epoch 313/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3545 - accuracy: 0.8014
# Epoch 314/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3526 - accuracy: 0.7957
# Epoch 315/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3521 - accuracy: 0.8006
# Epoch 316/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3534 - accuracy: 0.8001
# Epoch 317/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3523 - accuracy: 0.7975
# Epoch 318/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3509 - accuracy: 0.8021
# Epoch 319/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3539 - accuracy: 0.7992
# Epoch 320/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3511 - accuracy: 0.7992
# Epoch 321/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3508 - accuracy: 0.8043
# Epoch 322/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3501 - accuracy: 0.7960
# Epoch 323/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3513 - accuracy: 0.8001
# Epoch 324/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3467 - accuracy: 0.7997
# Epoch 325/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3472 - accuracy: 0.7997
# Epoch 326/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3454 - accuracy: 0.8053
# Epoch 327/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3477 - accuracy: 0.7909
# Epoch 328/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3485 - accuracy: 0.8001
# Epoch 329/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.3452 - accuracy: 0.7938
# Epoch 330/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3472 - accuracy: 0.8094
# Epoch 331/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3433 - accuracy: 0.7960
# Epoch 332/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3454 - accuracy: 0.8055
# Epoch 333/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3446 - accuracy: 0.8070
# Epoch 334/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3438 - accuracy: 0.8129
# Epoch 335/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3415 - accuracy: 0.7997
# Epoch 336/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3428 - accuracy: 0.7909
# Epoch 337/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3423 - accuracy: 0.8092
# Epoch 338/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3420 - accuracy: 0.8009
# Epoch 339/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3391 - accuracy: 0.8077
# Epoch 340/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3385 - accuracy: 0.8001
# Epoch 341/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3402 - accuracy: 0.8065
# Epoch 342/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3401 - accuracy: 0.7982
# Epoch 343/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3396 - accuracy: 0.8009
# Epoch 344/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3376 - accuracy: 0.8097
# Epoch 345/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3394 - accuracy: 0.7975
# Epoch 346/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3340 - accuracy: 0.8102
# Epoch 347/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3377 - accuracy: 0.8094
# Epoch 348/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3381 - accuracy: 0.8085
# Epoch 349/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3336 - accuracy: 0.8068
# Epoch 350/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3329 - accuracy: 0.8053
# Epoch 351/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3361 - accuracy: 0.8112
# Epoch 352/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3322 - accuracy: 0.8011
# Epoch 353/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3321 - accuracy: 0.8275
# Epoch 354/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3325 - accuracy: 0.8036
# Epoch 355/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3309 - accuracy: 0.7997
# Epoch 356/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3312 - accuracy: 0.8185
# Epoch 357/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3303 - accuracy: 0.8014
# Epoch 358/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3311 - accuracy: 0.8151
# Epoch 359/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3301 - accuracy: 0.8134
# Epoch 360/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3277 - accuracy: 0.8097
# Epoch 361/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3275 - accuracy: 0.8185
# Epoch 362/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3266 - accuracy: 0.8112
# Epoch 363/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3273 - accuracy: 0.8087
# Epoch 364/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3274 - accuracy: 0.8156
# Epoch 365/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3259 - accuracy: 0.8065
# Epoch 366/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3258 - accuracy: 0.8143
# Epoch 367/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3270 - accuracy: 0.8187
# Epoch 368/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3219 - accuracy: 0.8038
# Epoch 369/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3243 - accuracy: 0.8229
# Epoch 370/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3225 - accuracy: 0.8126
# Epoch 371/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3227 - accuracy: 0.8160
# Epoch 372/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3208 - accuracy: 0.8146
# Epoch 373/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3235 - accuracy: 0.8192
# Epoch 374/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3208 - accuracy: 0.8195
# Epoch 375/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3208 - accuracy: 0.8038
# Epoch 376/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3198 - accuracy: 0.8202
# Epoch 377/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3190 - accuracy: 0.8136
# Epoch 378/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3176 - accuracy: 0.8160
# Epoch 379/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3174 - accuracy: 0.8219
# Epoch 380/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3166 - accuracy: 0.8099
# Epoch 381/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3155 - accuracy: 0.8175
# Epoch 382/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3174 - accuracy: 0.8246
# Epoch 383/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3148 - accuracy: 0.8143
# Epoch 384/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3135 - accuracy: 0.8148
# Epoch 385/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3145 - accuracy: 0.8209
# Epoch 386/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3127 - accuracy: 0.8178
# Epoch 387/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3107 - accuracy: 0.8263
# Epoch 388/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3128 - accuracy: 0.8151
# Epoch 389/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3132 - accuracy: 0.8214
# Epoch 390/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3122 - accuracy: 0.8229
# Epoch 391/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3122 - accuracy: 0.8170
# Epoch 392/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3097 - accuracy: 0.8271
# Epoch 393/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3098 - accuracy: 0.8190
# Epoch 394/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3067 - accuracy: 0.8182
# Epoch 395/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3076 - accuracy: 0.8222
# Epoch 396/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3086 - accuracy: 0.8266
# Epoch 397/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3064 - accuracy: 0.8283
# Epoch 398/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3039 - accuracy: 0.8173
# Epoch 399/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3080 - accuracy: 0.8305
# Epoch 400/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3040 - accuracy: 0.8312
# Epoch 401/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3036 - accuracy: 0.8246
# Epoch 402/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3043 - accuracy: 0.8175
# Epoch 403/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3030 - accuracy: 0.8295
# Epoch 404/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3035 - accuracy: 0.8271
# Epoch 405/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3016 - accuracy: 0.8300
# Epoch 406/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3032 - accuracy: 0.8258
# Epoch 407/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3024 - accuracy: 0.8359
# Epoch 408/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3006 - accuracy: 0.8305
# Epoch 409/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2978 - accuracy: 0.8278
# Epoch 410/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.3011 - accuracy: 0.8312
# Epoch 411/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3006 - accuracy: 0.8202
# Epoch 412/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2972 - accuracy: 0.8322
# Epoch 413/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3010 - accuracy: 0.8305
# Epoch 414/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2999 - accuracy: 0.8217
# Epoch 415/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2947 - accuracy: 0.8393
# Epoch 416/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2945 - accuracy: 0.8278
# Epoch 417/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2952 - accuracy: 0.8295
# Epoch 418/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2940 - accuracy: 0.8422
# Epoch 419/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2943 - accuracy: 0.8256
# Epoch 420/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2945 - accuracy: 0.8373
# Epoch 421/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2918 - accuracy: 0.8300
# Epoch 422/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2925 - accuracy: 0.8388
# Epoch 423/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2925 - accuracy: 0.8410
# Epoch 424/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2927 - accuracy: 0.8280
# Epoch 425/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2945 - accuracy: 0.8322
# Epoch 426/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2892 - accuracy: 0.8341
# Epoch 427/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2914 - accuracy: 0.8386
# Epoch 428/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2937 - accuracy: 0.8258
# Epoch 429/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2902 - accuracy: 0.8231
# Epoch 430/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2879 - accuracy: 0.8295
# Epoch 431/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2864 - accuracy: 0.8393
# Epoch 432/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2878 - accuracy: 0.8378
# Epoch 433/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2846 - accuracy: 0.8439
# Epoch 434/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2875 - accuracy: 0.8356
# Epoch 435/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2899 - accuracy: 0.8349
# Epoch 436/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2831 - accuracy: 0.8373
# Epoch 437/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2841 - accuracy: 0.8361
# Epoch 438/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2840 - accuracy: 0.8449
# Epoch 439/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2820 - accuracy: 0.8395
# Epoch 440/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2832 - accuracy: 0.8488
# Epoch 441/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2828 - accuracy: 0.8305
# Epoch 442/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2815 - accuracy: 0.8430
# Epoch 443/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2811 - accuracy: 0.8410
# Epoch 444/1000
# 121/121 [==============================] - 2s 15ms/step - loss: 0.2853 - accuracy: 0.8432
# Epoch 445/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2793 - accuracy: 0.8383
# Epoch 446/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2778 - accuracy: 0.8422
# Epoch 447/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2782 - accuracy: 0.8393
# Epoch 448/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2789 - accuracy: 0.8469
# Epoch 449/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2777 - accuracy: 0.8371
# Epoch 450/1000
# ...
# Epoch 849/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1075 - accuracy: 0.9447
# Epoch 850/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1068 - accuracy: 0.9457
# Epoch 851/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.1093 - accuracy: 0.9430
# Epoch 852/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.1095 - accuracy: 0.9430
# Epoch 853/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1084 - accuracy: 0.9452
# Epoch 854/1000
# 121/121 [==============================] - 2s 19ms/step - loss: 0.1080 - accuracy: 0.9452
# Epoch 855/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.1065 - accuracy: 0.9425
# Epoch 856/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1097 - accuracy: 0.9455
# Epoch 857/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1086 - accuracy: 0.9467
# Epoch 858/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1035 - accuracy: 0.9457
# Epoch 859/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1120 - accuracy: 0.9440
# Epoch 860/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1041 - accuracy: 0.9477
# Epoch 861/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1061 - accuracy: 0.9457
# Epoch 862/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1048 - accuracy: 0.9455
# Epoch 863/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1084 - accuracy: 0.9467
# Epoch 864/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1065 - accuracy: 0.9462
# Epoch 865/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1041 - accuracy: 0.9459
# Epoch 866/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1027 - accuracy: 0.9477
# Epoch 867/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1053 - accuracy: 0.9467
# Epoch 868/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1043 - accuracy: 0.9472
# Epoch 869/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1020 - accuracy: 0.9472
# Epoch 870/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1025 - accuracy: 0.9486
# Epoch 871/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1022 - accuracy: 0.9464
# Epoch 872/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1021 - accuracy: 0.9486
# Epoch 873/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1035 - accuracy: 0.9457
# Epoch 874/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1025 - accuracy: 0.9474
# Epoch 875/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1049 - accuracy: 0.9467
# Epoch 876/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0988 - accuracy: 0.9477
# Epoch 877/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1006 - accuracy: 0.9501
# Epoch 878/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1033 - accuracy: 0.9464
# Epoch 879/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1050 - accuracy: 0.9462
# Epoch 880/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1001 - accuracy: 0.9494
# Epoch 881/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1000 - accuracy: 0.9474
# Epoch 882/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0985 - accuracy: 0.9511
# Epoch 883/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0997 - accuracy: 0.9506
# Epoch 884/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.0999 - accuracy: 0.9494
# Epoch 885/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0991 - accuracy: 0.9484
# Epoch 886/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0980 - accuracy: 0.9496
# Epoch 887/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0995 - accuracy: 0.9501
# Epoch 888/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0991 - accuracy: 0.9503
# Epoch 889/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.0973 - accuracy: 0.9508
# Epoch 890/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0951 - accuracy: 0.9530
# Epoch 891/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0950 - accuracy: 0.9513
# Epoch 892/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0969 - accuracy: 0.9521
# Epoch 893/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0987 - accuracy: 0.9481
# Epoch 894/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0970 - accuracy: 0.9516
# Epoch 895/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0978 - accuracy: 0.9484
# Epoch 896/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0948 - accuracy: 0.9521
# Epoch 897/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0979 - accuracy: 0.9486
# Epoch 898/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0978 - accuracy: 0.9525
# Epoch 899/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0964 - accuracy: 0.9496
# Epoch 900/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0943 - accuracy: 0.9501
# Epoch 901/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0934 - accuracy: 0.9516
# Epoch 902/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0924 - accuracy: 0.9518
# Epoch 903/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0939 - accuracy: 0.9543
# Epoch 904/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0952 - accuracy: 0.9499
# Epoch 905/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0945 - accuracy: 0.9508
# Epoch 906/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0906 - accuracy: 0.9525
# Epoch 907/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0928 - accuracy: 0.9552
# Epoch 908/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0914 - accuracy: 0.9540
# Epoch 909/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0931 - accuracy: 0.9525
# Epoch 910/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0930 - accuracy: 0.9523
# Epoch 911/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0903 - accuracy: 0.9538
# Epoch 912/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0895 - accuracy: 0.9543
# Epoch 913/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.0929 - accuracy: 0.9540
# Epoch 914/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0906 - accuracy: 0.9543
# Epoch 915/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0904 - accuracy: 0.9543
# Epoch 916/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.0925 - accuracy: 0.9501
# Epoch 917/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0921 - accuracy: 0.9530
# Epoch 918/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0903 - accuracy: 0.9525
# Epoch 919/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0890 - accuracy: 0.9543
# Epoch 920/1000
# 121/121 [==============================] - 2s 16ms/step - loss: 0.0889 - accuracy: 0.9543
# Epoch 921/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0909 - accuracy: 0.9533
# Epoch 922/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0889 - accuracy: 0.9538
# Epoch 923/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0883 - accuracy: 0.9560
# Epoch 924/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0881 - accuracy: 0.9555
# Epoch 925/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0891 - accuracy: 0.9528
# Epoch 926/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0878 - accuracy: 0.9550
# Epoch 927/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0881 - accuracy: 0.9577
# Epoch 928/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0876 - accuracy: 0.9555
# Epoch 929/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0855 - accuracy: 0.9550
# Epoch 930/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0878 - accuracy: 0.9550
# Epoch 931/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0870 - accuracy: 0.9562
# Epoch 932/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0858 - accuracy: 0.9565
# Epoch 933/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0844 - accuracy: 0.9584
# Epoch 934/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0895 - accuracy: 0.9506
# Epoch 935/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0866 - accuracy: 0.9572
# Epoch 936/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0889 - accuracy: 0.9545
# Epoch 937/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0842 - accuracy: 0.9567
# Epoch 938/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0876 - accuracy: 0.9555
# Epoch 939/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0871 - accuracy: 0.9560
# Epoch 940/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0842 - accuracy: 0.9550
# Epoch 941/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0806 - accuracy: 0.9596
# Epoch 942/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0867 - accuracy: 0.9560
# Epoch 943/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0892 - accuracy: 0.9550
# Epoch 944/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0843 - accuracy: 0.9579
# Epoch 945/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0819 - accuracy: 0.9587
# Epoch 946/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0821 - accuracy: 0.9587
# Epoch 947/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0824 - accuracy: 0.9572
# Epoch 948/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0804 - accuracy: 0.9587
# Epoch 949/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0829 - accuracy: 0.9587
# Epoch 950/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0793 - accuracy: 0.9582
# Epoch 951/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0792 - accuracy: 0.9594
# Epoch 952/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0849 - accuracy: 0.9560
# Epoch 953/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0819 - accuracy: 0.9587
# Epoch 954/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0830 - accuracy: 0.9587
# Epoch 955/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0827 - accuracy: 0.9577
# Epoch 956/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0808 - accuracy: 0.9572
# Epoch 957/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0800 - accuracy: 0.9589
# Epoch 958/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0818 - accuracy: 0.9599
# Epoch 959/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0781 - accuracy: 0.9596
# Epoch 960/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0794 - accuracy: 0.9611
# Epoch 961/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0776 - accuracy: 0.9589
# Epoch 962/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0775 - accuracy: 0.9591
# Epoch 963/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0772 - accuracy: 0.9633
# Epoch 964/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0790 - accuracy: 0.9572
# Epoch 965/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0774 - accuracy: 0.9596
# Epoch 966/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0856 - accuracy: 0.9569
# Epoch 967/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0774 - accuracy: 0.9594
# Epoch 968/1000
# 121/121 [==============================] - 2s 20ms/step - loss: 0.0763 - accuracy: 0.9604
# Epoch 969/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0781 - accuracy: 0.9614
# Epoch 970/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0761 - accuracy: 0.9596
# Epoch 971/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0786 - accuracy: 0.9601
# Epoch 972/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0771 - accuracy: 0.9611
# Epoch 973/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0775 - accuracy: 0.9616
# Epoch 974/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0750 - accuracy: 0.9621
# Epoch 975/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0798 - accuracy: 0.9616
# Epoch 976/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0750 - accuracy: 0.9601
# Epoch 977/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0750 - accuracy: 0.9606
# Epoch 978/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0748 - accuracy: 0.9611
# Epoch 979/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0746 - accuracy: 0.9618
# Epoch 980/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0730 - accuracy: 0.9640
# Epoch 981/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0731 - accuracy: 0.9636
# Epoch 982/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0736 - accuracy: 0.9638
# Epoch 983/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0729 - accuracy: 0.9638
# Epoch 984/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0741 - accuracy: 0.9623
# Epoch 985/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0759 - accuracy: 0.9601
# Epoch 986/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0747 - accuracy: 0.9596
# Epoch 987/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0769 - accuracy: 0.9621
# Epoch 988/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0740 - accuracy: 0.9609
# Epoch 989/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0722 - accuracy: 0.9643
# Epoch 990/1000
# 121/121 [==============================] - 2s 19ms/step - loss: 0.0718 - accuracy: 0.9628
# Epoch 991/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0730 - accuracy: 0.9633
# Epoch 992/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0713 - accuracy: 0.9626
# Epoch 993/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0720 - accuracy: 0.9645
# Epoch 994/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0707 - accuracy: 0.9636
# Epoch 995/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0730 - accuracy: 0.9611
# Epoch 996/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0706 - accuracy: 0.9658
# Epoch 997/1000
# 121/121 [==============================] - 2s 19ms/step - loss: 0.0705 - accuracy: 0.9636
# Epoch 998/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0703 - accuracy: 0.9643
# Epoch 999/1000
# 121/121 [==============================] - 2s 18ms/step - loss: 0.0711 - accuracy: 0.9643
# Epoch 1000/1000
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0699 - accuracy: 0.9640

# %%
from sklearn.metrics import confusion_matrix
y_pred=[]
for i in model2.predict(X_test_std):
    if i>0.5:
        y_pred.append(1)
    if i<0.5:
        y_pred.append(0)
confusion_matrix(Y_test,y_pred)
# Out:
# array([[896,  86],
#        [ 29,  11]])

# %% [markdown]
# F1 SCORE AND ALL

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(Y_test,y_pred)
accuracy
# Out:
# 0.8874755381604696

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
print(classification_report(Y_test, y_pred))
print('Accuracy score: ', round(accuracy_score(Y_test, y_pred), 2))
print('F1 Score: ', round(f1_score(Y_test, y_pred), 2))
print('Confusion Matrix: ', confusion_matrix(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       982
#            1       0.11      0.28      0.16        40
#
#     accuracy                           0.89      1022
#    macro avg       0.54      0.59      0.55      1022
# weighted avg       0.94      0.89      0.91      1022
#
# Accuracy score:  0.89
# F1 Score:  0.16
# Confusion Matrix:  [[896  86]
#  [ 29  11]]

# %%
predict_x=model2.predict(X_test_std) 
classes_x=np.argmax(predict_x,axis=1)
# predictions= model2.predict(X_test_std)

# %%
sum(predict_x)
# Out:
# array([65.75247], dtype=float32)

# %%
from sklearn.metrics import f1_score, recall_score
#print(f1_score(Y_test, predict_x))

# %%
# Create function
def nn_cl_bo2(neurons, activation, optimizer, learning_rate, batch_size, epochs,
              layers1, layers2, normalization, dropout, dropout_rate):
    optimizerL = ['SGD', 'Adam', 'RMSprop', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl','SGD']
    optimizerD= {'Adam':Adam(lr=learning_rate), 'SGD':SGD(lr=learning_rate),
                 'RMSprop':RMSprop(lr=learning_rate), 'Adadelta':Adadelta(lr=learning_rate),
                 'Adagrad':Adagrad(lr=learning_rate), 'Adamax':Adamax(lr=learning_rate),
                 'Nadam':Nadam(lr=learning_rate), 'Ftrl':Ftrl(lr=learning_rate)}
    activationL = ['relu', 'sigmoid', 'softplus', 'softsign', 'tanh', 'selu',
                   'elu', 'exponential', LeakyReLU,'relu']
    neurons = round(neurons)
    activation = activationL[round(activation)]
    optimizer = optimizerD[optimizerL[round(optimizer)]]
    batch_size = round(batch_size)
    epochs = round(epochs)
    layers1 = round(layers1)
    layers2 = round(layers2)
    def nn_cl_fun():
        nn = Sequential()
        nn.add(Dense(neurons, input_dim=10, activation=activation))
        if normalization > 0.5:
            nn.add(BatchNormalization())
        for i in range(layers1):
            nn.add(Dense(neurons, activation=activation))
        if dropout > 0.5:
            nn.add(Dropout(dropout_rate, seed=123))
        for i in range(layers2):
            nn.add(Dense(neurons, activation=activation))
        nn.add(Dense(1, activation='sigmoid'))
        nn.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
        return nn
    es = EarlyStopping(monitor='accuracy', mode='max', verbose=0, patience=20)
    nn = KerasClassifier(build_fn=nn_cl_fun, epochs=epochs, batch_size=batch_size, verbose=0)
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
    score = cross_val_score(nn, X_train, y_train, scoring=score_acc, cv=kfold, fit_params={'callbacks':[es]}).mean()
    return score

# %%
params_nn2 ={
    'neurons': (10, 100),
    'activation':(0, 9),
    'optimizer':(0,7),
    'learning_rate':(0.01, 1),
    'batch_size':(200, 1000),
    'epochs':(20, 100),
    'layers1':(1,3),
    'layers2':(1,3),
    'normalization':(0,1),
    'dropout':(0,1),
    'dropout_rate':(0,0.3)
}
# Run Bayesian Optimization
nn_bo = BayesianOptimization(nn_cl_bo2, params_nn2, random_state=111)
nn_bo.maximize(init_points=25, n_iter=4)

# %%
params_nn_ = nn_bo.max['params']
learning_rate = params_nn_['learning_rate']
activationL = ['relu', 'sigmoid', 'softplus', 'softsign', 'tanh', 'selu',
               'elu', 'exponential', LeakyReLU,'relu']
params_nn_['activation'] = activationL[round(params_nn_['activation'])]
params_nn_['batch_size'] = round(params_nn_['batch_size'])
params_nn_['epochs'] = round(params_nn_['epochs'])
params_nn_['layers1'] = round(params_nn_['layers1'])
params_nn_['layers2'] = round(params_nn_['layers2'])
params_nn_['neurons'] = round(params_nn_['neurons'])
optimizerL = ['Adam', 'SGD', 'RMSprop', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl','Adam']
optimizerD= {'Adam':Adam(lr=learning_rate), 'SGD':SGD(lr=learning_rate),
             'RMSprop':RMSprop(lr=learning_rate), 'Adadelta':Adadelta(lr=learning_rate),
             'Adagrad':Adagrad(lr=learning_rate), 'Adamax':Adamax(lr=learning_rate),
             'Nadam':Nadam(lr=learning_rate), 'Ftrl':Ftrl(lr=learning_rate)}
params_nn_['optimizer'] = optimizerD[optimizerL[round(params_nn_['optimizer'])]]
params_nn_

# %%
# Fitting Neural Network
def nn_cl_fun():
nn = Sequential()
nn.add(Dense(params_nn_['neurons'], input_dim=10, activation=params_nn_['activation']))
    if params_nn_['normalization'] > 0.5:
nn.add(BatchNormalization())
    for i in range(params_nn_['layers1']):
nn.add(Dense(params_nn_['neurons'], activation=params_nn_['activation']))
    if params_nn_['dropout'] > 0.5:
nn.add(Dropout(params_nn_['dropout_rate'], seed=123))
    for i in range(params_nn_['layers2']):
nn.add(Dense(params_nn_['neurons'], activation=params_nn_['activation']))
nn.add(Dense(1, activation='sigmoid'))
nn.compile(loss='binary_crossentropy', optimizer=params_nn_['optimizer'], metrics=['accuracy'])
    return nn
es = EarlyStopping(monitor='accuracy', mode='max', verbose=0, patience=20)
nn = KerasClassifier(build_fn=nn_cl_fun, epochs=params_nn_['epochs'], batch_size=params_nn_['batch_size'],
                         verbose=0)
 nn.fit(X_train, y_train, validation_data=(X_val, y_val), verbose=1)
